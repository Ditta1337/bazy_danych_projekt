# %% [markdown]
# # Database data generator

# %% [markdown]
# ### 1. Import libraries

# %%
import pyodbc
import hashlib
from faker import Faker 
from datetime import datetime, time
import random
from utils import *
import numpy as np
import pandas as pd

# .  ...  ...   ..   ..   ..   ...  ...  ...   ..   ..   ..   ...  ...   ..   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..   ..   ..   ...  ...  ...   ..   ..   ..   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   ...  ... (@@@@&%%%@&%%@#&@..   ...  ...  ...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..  &&%#@&@@@@@@@@@@@@@@@@@@@@@@@@@@ .   ..   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   &.&@@@@@@@@@@@@@@@@@@@@@@@@@&@@@@@@@@..   ..   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...  &/&(@@@&&@&@@@@@@@@@@@@@@@@@@&@@@&@@@@&@#@ .   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..  /@@&&@#%&&@@@@@@@@@@@@@@@@@@@@@@@%&@@@&@&&%@@&&@..   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  @&@&@&,@&%@@@@@@@@@@@@@@@@@@@@&@@@@@@@@@%@#*@&@&@&% ...  ...  ...   ..   ..   .
# .  ...  ...   ..   .@%&@@@(((%@@@@@@@@@@@@@@@@@@@@@@@&&@@#%%@&@&#@@@&#&@@   ..   ..   ...  ...  ... 
#  ..   ..   ..   ....@&%%(.%&@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&%@&&&/&&@@%%/%%@.  ...  ...   ..   ..   .
# .  ...  ...   ..  #%/%#&&@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&&#&@%&%(&#(*%% ..   ..   ...  ...  ... 
#  ..   ..   ..   ..%#%# *(@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@&@&&@@@@@#%%&#(@&(#.  ...  ...   ..   ..   .
# .  ...  ...   .. .#%&//,&@@@@@@@@@@@@@@@@@@@@@@@@@@@&@@@@&&#@@&%&(&&%##%(%(%..   ..   ...  ...  ... 
#  ..   ..   ..   ../#* &#@@/@@@@@@@@@@@@@@@@@@@@@@@@@@@&@@&&&&%@@@@&&%(##(#,/  ...  ...   ..   ..   .
# .  ...  ...   ..  /*./#(&@@@&@@@@@@@@@@@@@@@@@@@@@@@@&@%@&&&&%&&%%%&#/%/&,*#..   ..   ...  ...  ... 
#  ..   ..   ..   ...*&,*#%@%@%%%@@@@@@@@@@@@@@@@@@@@@@@@@&&@@@##(&&#&%/%(#**.  ...  ...   ..   ..   .
# .  ...  ...   ..   .(%#(#@#&&@@&@@@@@@@@@@@@@@@@@@@@@@@@@&%&&&&%((#%%&@@#/  ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ,@%(@%&# .&@@@@@@@@@@&&%%%#%%%#((#@@@@@@&/    .*@%%#...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..  %%,*%@@@%&@&&%%##&&@@@@@@@@/(%&&@@@&@&%//@@& ,/((.   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  .../#&%@@@@@@@@@@@@@%&@@@&(((**/#%%#/*/****@.   ,*.,/..  ...  ...   ..   ..   .
#                        #%.  *%/(%@&&&%%%&%&@@&(/&@(,,*/((/*/*.  #     *, /                          
# .  ...  ...   ..   ..  &*(  ..@#&&%%%%%%&@&@@&(,..&@ */**/*** @  ..   //    ..   ..   ..   ...  ... 
#  ..   ..   ..   ...  ...(&%,*(%@@@&%%%&&&@@@@#(*,,.,*((((/**,,,,.,.. *,  ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ./#**#%&@@@@&&&&@@@@@@%(/***,////***,,*,,,,. ,...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   #/((&@@@@@@@@@@@@@@@&#***,*,***,,,,,,,,.. .   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   /#%%@@@@@@@@@@@&#**#*,..,...,,,,..,..... ...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ...(#&&@@@@@@@@@@@@@@#(##%,*/,,,,,,,,,,,...   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   ..(#%&&@@@@@@@@@#(///*,,,,//**,,,,*,,,.  ...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..   ##&&&@@@@@@@@@&&&&%(/************.  ..   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   ...  /##%&@@@@@&&##*/*,,,,**,*,**......  ...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..   ..,(#/#%&@@@@@&%##//**,,**/,,,. .   ..   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   ...  */%&&&%%@@@@@&&&&%#(((*,,.........  ...   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..   ..*(#&@@@&&@@@@@@&%(/*,,,........,  ..   ...  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   ..   ..*&@,/%&@@@@@@@@&&&%(//*,,,,........###(///   ..   ..   ...  ...  ... 
#  ..   ..   ..   ...  ...   ..#&@@@*(#&@@@@@@@&&&&%(/*,,,,,.........,&&%##//*  ...  ...   ..   ..   .
# .  ...  ...   ..   ..   *%%(#@@@@@((%&&@&&&&&&%###//*,,,.,..........  #@(#///*   ..   ...  ...  ... 
#  ..   ..   ..   ...  #@@@&##&&&@@@@@&&&&&&%%#%%##((//**,,,.......     .((#////*/*  ...   ..   ..   .
# .  ...  ...   . /(%&&@@@@&#%&&%%@&@@@@@&&&%(#(((((///**,,,,.....      ,**(/////////@&&(..  ...  ... 
#  ..   ..%@@%&@@@&&&&&&@@@&%%&&%#&&%(,&&&&&%#(///////***,,,..          ,*(/////////////#&@&, .&..   .

# %%
CONNECTION_STRING = "DRIVER={SQL Server};SERVER=your_server;DATABASE=your_database;UID=your_username;PWD=your_password"

# %% [markdown]
# ### 2. Establish connection with database

# %%
#connection = pyodbc.connect(CONNECTION_STRING)
#cursor = connection.cursor()

fake = Faker()

# %% [markdown]
# ### 3. Define generating functions

# %%
def fill_students(num_records):
    for i in range(num_records):
        first_name = fake.first_name()
        last_name = fake.last_name()
        email = first_name + last_name + "@gmail.com"
        password_not_hashed = fake.password()
        sha256_hash = hashlib.sha256()
        sha256_hash.update(password_not_hashed.encode('utf-8'))
        password = sha256_hash.hexdigest()[:20]
    

        with open('data/students.csv', 'a') as f:
            f.write(f"{first_name},{last_name},{email},{password}\n")

        # cursor.execute("INSERT INTO students (first_name, last_name, email, password) VALUES (?, ?, ?, ?)",
        #                   first_name,
        #                   last_name,
        #                   email,
        #                   password)
        
        # connection.commit()

def fill_lecturers(num_records):
    for _ in range(num_records):
        first_name = fake.first_name()
        last_name = fake.last_name()
        title = random.choice(["prof.", "dr.", "mgr.", None])
        email = first_name + last_name + "@gmail.com"
        password_not_hashed = fake.password()
        sha256_hash = hashlib.sha256()
        sha256_hash.update(password_not_hashed.encode('utf-8'))
        password = sha256_hash.hexdigest()[:20]

        with open('data/lecturers.csv', 'a') as f:
            f.write(f"{first_name},{last_name},{email},{password},{title}\n")


def fill_employees(num_records):
    for _ in range(num_records):
        first_name = fake.first_name()
        last_name = fake.last_name()
        email = first_name + last_name + "@gmail.com"
        password_not_hashed = fake.password()
        role_id = random.randint(1, 6)
        sha256_hash = hashlib.sha256()
        sha256_hash.update(password_not_hashed.encode('utf-8'))
        password = sha256_hash.hexdigest()[:20]

        with open('data/employees.csv', 'a') as f:
            f.write(f"{first_name},{last_name},{role_id},{email},{password}\n")

        # cursor.execute("INSERT INTO employees (first_name, last_name, email, password) VALUES (?, ?, ?, ?)",
        #                   first_name,
        #                   last_name,
        #                   email,
        #                   password)
        
        # connection.commit()

def fill_lessons(num_records,
                course_id,
                date_range_start,
                date_range_end,
                price,
                students_limit,
                translator_id,):
    dates = generate_dates(date_range_start, date_range_end, num_records)
    for i in range(num_records):
        name = fake.word() + "ing lesson"
        description = name + " description"
        date = dates[i]
        lecturer_id = random.randint(1, 10)
        start_time = (datetime.strptime("08:00", "%H:%M") + timedelta(minutes=random.randint(0, 600))).time()
        end_time = (datetime.combine(datetime.today(), start_time) + timedelta(hours=1, minutes=30)).time()
        classroom = random.choice(["A1", "A2", "A3", "A4", "A5", "B1", "B2", "B3", "B4", "B5", "C1", "C2", "C3", "C4", "C5", "Online",
         "Online", "Online"])
        student_limit_tmp = students_limit
        if classroom == "Online":
            student_limit_tmp = None

        with open('data/lessons.csv', 'a') as f:
            f.write(f"{course_id},{lecturer_id},{name},{description},{date},{start_time},{end_time},{price},{student_limit_tmp},{classroom},{translator_id}\n")

def fill_courses(num_records,
                 study_id,
                 entry_price,
                 full_price,
                 students_limit):
    
    for _ in range(num_records):
        name = fake.word() + "ing course"
        description = name + " description"

        with open('data/courses.csv', 'a') as f:
            f.write(f"{study_id},{name},{description},{entry_price},{full_price},{students_limit}\n")
  
def fill_studies(
        entry_fee,
        students_limit,
        exam_date,
        employee_id,
        ):

        name = fake.word() + "ing study"
        exam_date = datetime.strptime(exam_date, "%Y-%m-%d").date()
        description = name + " description"

        with open('data/studies.csv', 'a') as f:
            f.write(f"{name},{description},{entry_fee},{students_limit},{exam_date},{employee_id}\n")
            f.write("\n")

     
def fill_roles(roles):
    for i in range(len(roles)):
        with open('data/roles.csv', 'a') as f:
            f.write(f"{roles[i]}\n")


def fill_internships(num_records,
                     student_id,
                    study_id,
                    start_date,
                    end_date):
    dates = generate_dates(start_date, end_date, 100)

    for i in range(num_records):
        company = random.choice(["Google", "Microsoft", "Facebook", "Apple", "Amazon", "COMARCH", "Aptiv", "OpenAI", "Motorola", "Intel", "IBM", "Oracle", "Cisco", "SAP", "Adobe", "Nvidia", "PayPal", "Salesforce", "VMware", "Dell", "HP", "Lenovo", "Huawei", "Xiaomi", "Sony", "Samsung", "LG", "Panasonic", "Philips", "Toshiba", "Hitachi", "Siemens", "Bosch", "Alibaba", "Tencent", "Baidu", "JD.com", "Uber", "Airbnb", "Netflix", "Spotify", "TikTok", "Snapchat", "Twitter", "Pinterest", "Reddit", "Quora", "Dropbox", "Epic Games", "Unity", "Activision Blizzard", "Electronic Arts", "Take-Two Interactive", "CD Projekt", "Ubisoft", "Capcom", "Konami", "Square Enix", "Bandai Namco", "Sega", "Atlus", "Koei Tecmo", "Nexon", "NCSoft", "Netmarble", "Zynga", "Gameloft", "Glu Mobile", "Rovio", "King", "Supercell", "Garena", "Tencent Games", "Nintendo", "Sony Interactive Entertainment", "Microsoft Studios", "Activision", "Electronic Arts", "Ubisoft", "Take-Two Interactive", "Bandai Namco", "Konami", "Square Enix", "Capcom", "Sega", "Atlus", "Koei Tecmo", "Nexon", "NCSoft", "Netmarble", "Zynga", "Gameloft", "Glu Mobile", "Rovio", "King", "Supercell", "Garena", "Tencent Games", "Nintendo", "Sony Interactive Entertainment", "Microsoft Studios", "Activision Blizzard", "Electronic Arts", "Ubisoft", "Take-Two Interactive", "Bandai Namco", "Konami", "Square Enix", "Capcom", "Sega", "Atlus", "Koei Tecmo", "Nexon", "NCSoft", "Netmarble", "Zynga", "Gameloft", "Glu Mobile", "Rovio", "King", "Supercell", "Garena", "Tencent Games", "Nintendo"])
        description = "Internship at " + company
        date = random.choice(dates)
    
        with open('data/internships.csv', 'a') as f:
            f.write(f"{student_id},{study_id},{company},{description},{date}\n")
    

def fill_materials(lesson_id):

    name = fake.word() + "ing material"
    description = name + " material description"
    file_url = "https://TheBestUni.com/materials/"+ name.replace(" ", "_") + ".avi"

    with open('data/materials.csv', 'a') as f:
        f.write(f"{lesson_id},{name},{description},{file_url}\n")


def fill_attendence(student_id, lesson_id):
    attendence_status = np.random.choice([1, 0], p=[0.9, 0.1])
    with open('data/attendence.csv', 'a') as f:
        f.write(f"{lesson_id},{student_id},{attendence_status}\n")



def fill_lesson_payments(student_id, lesson_id, payment_id):
    with open('data/lesson_payments.csv', 'a') as f:
        f.write(f"{student_id},{lesson_id},{payment_id}\n")

    # cursor.execute("INSERT INTO lesson_payments (student_id, lesson_id) VALUES (?, ?)",
    #                   lesson_id,
    #                   student_id)
    

    # connection.commit()

def fill_course_payments(student_id, course_id, payment_id):
    is_full_price = np.random.choice([1, 0], p=[0.9, 0.1])
    with open('data/course_payments.csv', 'a') as f:
        f.write(f"{student_id},{course_id},{payment_id},{is_full_price}\n")


def fill_payments(date):
    status = np.random.choice([1, 0], p=[0.95, 0.05])
    date = (datetime.strptime(date, "%Y-%m-%d").date() - timedelta(days=random.randint(0, 30))).strftime("%Y-%m-%d")
    payment_url = "https://PayPal.com/payment/" + str(fake.random_int(min=1000000000000000, max=9999999999999999))
    with open('data/payments.csv', 'a') as f:
        f.write(f"{status},{date},{payment_url}\n")


def fill_study_payments(student_id, study_id, payment_id):
    with open('data/study_payments.csv', 'a') as f:
        f.write(f"{student_id},{study_id},{payment_id}\n")


def fill_shopping_carts(student_id, payment_id):
    with open('data/shopping_carts.csv', 'a') as f:
        f.write(f"{student_id},{payment_id}\n")


def fill_lessons_items(cart_id, lesson_id):
    with open('data/lessons_items.csv', 'a') as f:
        f.write(f"{cart_id},{lesson_id}\n")


def fill_courses_items(cart_id, course_id):
    with open('data/courses_items.csv', 'a') as f:
        f.write(f"{cart_id},{course_id}\n")


def fill_studies_items(cart_id, study_id):
    with open('data/studies_items.csv', 'a') as f:
        f.write(f"{cart_id},{study_id}\n")

# %% [markdown]
# Study 1:
#     Courses: 1 - 8
#     Lessons: 1 - 48
#     Students: 1 - 35
#     Payments: 1 - 35
#
# Course 1:
#     Lessons: 49 - 68
#     Students: 36 - 85
#     Payments: 36 - 85
#     Full_price = 1200
#     Entry_price = 50
#
# 5 Webinars:
#     Lessons 69 - 74
#     Students 86 - 100

# %% [markdown]
# ### 4. Invoke functions and close connection

# %%
payment_id = [86]

# %%
#fill_lessons(5, None, "2023-07-01", "2023-10-31", 99.99, 100, 8)
#fill_students(15)

# for student in range(23, 35):
#     for lesson in [73]:
#         fill_attendence(student, lesson)
#         fill_lesson_payments(student, lesson, payment_id[0])
#         fill_payments
#         payment_id[0] += 1

with open("data_v01/lessons.csv", "r") as f:
    lessons = f.readlines()

for lesson in lessons:
    lesson = lesson.split(",")
    price = float(lesson[7])
    # insert payment increased by 10% right to the price
    # only to the 2 decimal places
    lesson.insert(8, str(round(price * 1.1, 2)))
    lesson = ",".join(lesson)
    print(lesson)
    with open("data_v01/lessons.csv", "a") as f:
        f.write(lesson)
# Out:
# 1,3,coaching lesson,coaching lesson description,2024-01-01,08:12:00,09:42:00,65,71.5,35,C1,6
#
# 1,6,maybeing lesson,maybeing lesson description,2024-01-07,16:25:00,17:55:00,65,71.5,35,C2,6
#
# 1,3,stageing lesson,stageing lesson description,2024-01-13,14:54:00,16:24:00,65,71.5,None,Online,6
#
# 1,8,catching lesson,catching lesson description,2024-01-19,10:37:00,12:07:00,65,71.5,35,A4,6
#
# 1,4,continueing lesson,continueing lesson description,2024-01-25,08:25:00,09:55:00,65,71.5,35,C5,6
#
# 1,3,cameraing lesson,cameraing lesson description,2024-01-31,16:26:00,17:56:00,65,71.5,35,A1,6
#
# 2,1,civiling lesson,civiling lesson description,2024-02-01,13:53:00,15:23:00,75,82.5,35,B5,7
#
# 2,8,necessarying lesson,necessarying lesson description,2024-02-06,10:41:00,12:11:00,75,82.5,35,B3,7
#
# 2,1,developmenting lesson,developmenting lesson description,2024-02-12,10:18:00,11:48:00,75,82.5,35,B5,7
#
# 2,5,perhapsing lesson,perhapsing lesson description,2024-02-17,11:16:00,12:46:00,75,82.5,35,A4,7
#
# 2,7,establishing lesson,establishing lesson description,2024-02-23,13:02:00,14:32:00,75,82.5,35,B3,7
#
# 2,5,fishing lesson,fishing lesson description,2024-02-29,16:15:00,17:45:00,75,82.5,None,Online,7
#
# 3,2,radioing lesson,radioing lesson description,2024-03-01,12:33:00,14:03:00,70,77.0,35,B1,7
#
# 3,1,borning lesson,borning lesson description,2024-03-07,15:49:00,17:19:00,70,77.0,35,A3,7
#
# 3,3,fewing lesson,fewing lesson description,2024-03-13,14:31:00,16:01:00,70,77.0,35,A4,7
#
# 3,3,largeing lesson,largeing lesson description,2024-03-19,16:01:00,17:31:00,70,77.0,35,C3,7
#
# 3,2,finishing lesson,finishing lesson description,2024-03-25,11:39:00,13:09:00,70,77.0,35,A2,7
#
# 3,9,amounting lesson,amounting lesson description,2024-03-31,15:16:00,16:46:00,70,77.0,35,A2,7
#
# 4,10,nexting lesson,nexting lesson description,2024-04-01,16:05:00,17:35:00,60,66.0,35,B2,6
#
# 4,10,forming lesson,forming lesson description,2024-04-06,11:41:00,13:11:00,60,66.0,35,C1,6
#
# 4,5,evidenceing lesson,evidenceing lesson description,2024-04-12,13:10:00,14:40:00,60,66.0,35,B1,6
#
# 4,6,justing lesson,justing lesson description,2024-04-18,15:48:00,17:18:00,60,66.0,35,B2,6
#
# 4,2,almosting lesson,almosting lesson description,2024-04-24,09:41:00,11:11:00,60,66.0,35,A2,6
#
# 4,9,marketing lesson,marketing lesson description,2024-04-30,11:35:00,13:05:00,60,66.0,35,A1,6
#
# 5,10,possibleing lesson,possibleing lesson description,2024-05-01,16:09:00,17:39:00,80,88.0,35,A3,9
#
# 5,5,certaining lesson,certaining lesson description,2024-05-07,13:28:00,14:58:00,80,88.0,35,C1,9
#
# 5,5,controling lesson,controling lesson description,2024-05-13,16:05:00,17:35:00,80,88.0,35,A2,9
#
# 5,3,remaining lesson,remaining lesson description,2024-05-19,09:18:00,10:48:00,80,88.0,35,B3,9
#
# 5,1,collegeing lesson,collegeing lesson description,2024-05-25,16:12:00,17:42:00,80,88.0,35,C1,9
#
# 5,3,priceing lesson,priceing lesson description,2024-05-31,14:25:00,15:55:00,80,88.0,35,A4,9
#
# 6,8,managementing lesson,managementing lesson description,2024-06-01,08:48:00,10:18:00,80,88.0,35,B2,9
#
# 6,7,socialing lesson,socialing lesson description,2024-06-06,14:47:00,16:17:00,80,88.0,35,B4,9
#
# 6,1,leveling lesson,leveling lesson description,2024-06-12,08:42:00,10:12:00,80,88.0,35,B3,9
#
# 6,9,springing lesson,springing lesson description,2024-06-18,10:10:00,11:40:00,80,88.0,35,C4,9
#
# 6,3,howevering lesson,howevering lesson description,2024-06-24,12:21:00,13:51:00,80,88.0,35,B3,9
#
# 6,4,moderning lesson,moderning lesson description,2024-06-30,15:51:00,17:21:00,80,88.0,35,C5,9
#
# 7,1,againing lesson,againing lesson description,2024-10-01,15:23:00,16:53:00,75,82.5,35,B5,6
#
# 7,6,summering lesson,summering lesson description,2024-10-07,14:34:00,16:04:00,75,82.5,None,Online,6
#
# 7,5,millioning lesson,millioning lesson description,2024-10-13,12:18:00,13:48:00,75,82.5,35,B1,6
#
# 7,8,successfuling lesson,successfuling lesson description,2024-10-19,13:27:00,14:57:00,75,82.5,35,A5,6
#
# 7,4,radioing lesson,radioing lesson description,2024-10-25,14:29:00,15:59:00,75,82.5,35,C5,6
#
# 7,8,southing lesson,southing lesson description,2024-10-31,11:34:00,13:04:00,75,82.5,35,C2,6
#
# 8,9,blooding lesson,blooding lesson description,2024-11-01,08:34:00,10:04:00,65,71.5,35,C2,7
#
# 8,2,differenceing lesson,differenceing lesson description,2024-11-06,13:26:00,14:56:00,65,71.5,35,A1,7
#
# 8,3,buting lesson,buting lesson description,2024-11-12,16:50:00,18:20:00,65,71.5,35,B3,7
#
# 8,2,executiveing lesson,executiveing lesson description,2024-11-18,14:06:00,15:36:00,65,71.5,35,B4,7
#
# 8,10,womaning lesson,womaning lesson description,2024-11-24,11:06:00,12:36:00,65,71.5,None,Online,7
#
# 8,9,wideing lesson,wideing lesson description,2024-11-30,15:04:00,16:34:00,65,71.5,35,A4,7
#
# 9,1,businessing lesson,businessing lesson description,2023-05-01,08:56:00,10:26:00,60,66.0,None,Online,7
#
# 9,1,officering lesson,officering lesson description,2023-05-04,13:38:00,15:08:00,60,66.0,75,B5,7
#
# 9,5,insteading lesson,insteading lesson description,2023-05-07,09:53:00,11:23:00,60,66.0,None,Online,7
#
# 9,2,seeking lesson,seeking lesson description,2023-05-10,14:52:00,16:22:00,60,66.0,75,A2,7
#
# 9,2,styleing lesson,styleing lesson description,2023-05-13,09:29:00,10:59:00,60,66.0,75,C2,7
#
# 9,4,campaigning lesson,campaigning lesson description,2023-05-16,10:20:00,11:50:00,60,66.0,75,C3,7
#
# 9,7,quiteing lesson,quiteing lesson description,2023-05-19,17:51:00,19:21:00,60,66.0,75,A4,7
#
# 9,4,itsing lesson,itsing lesson description,2023-05-23,14:51:00,16:21:00,60,66.0,75,A4,7
#
# 9,3,themselvesing lesson,themselvesing lesson description,2023-05-26,12:57:00,14:27:00,60,66.0,75,C4,7
#
# 9,10,agreementing lesson,agreementing lesson description,2023-05-29,08:31:00,10:01:00,60,66.0,None,Online,7
#
# 9,1,industrying lesson,industrying lesson description,2023-06-01,16:59:00,18:29:00,60,66.0,75,A4,7
#
# 9,2,consumering lesson,consumering lesson description,2023-06-04,17:09:00,18:39:00,60,66.0,75,B2,7
#
# 9,5,energying lesson,energying lesson description,2023-06-07,10:31:00,12:01:00,60,66.0,75,B5,7
#
# 9,4,thirding lesson,thirding lesson description,2023-06-11,15:07:00,16:37:00,60,66.0,75,A2,7
#
# 9,4,gardening lesson,gardening lesson description,2023-06-14,15:47:00,17:17:00,60,66.0,75,B3,7
#
# 9,8,borning lesson,borning lesson description,2023-06-17,08:51:00,10:21:00,60,66.0,75,A2,7
#
# 9,4,seriesing lesson,seriesing lesson description,2023-06-20,12:30:00,14:00:00,60,66.0,75,B1,7
#
# 9,8,centraling lesson,centraling lesson description,2023-06-23,09:19:00,10:49:00,60,66.0,75,A5,7
#
# 9,1,riching lesson,riching lesson description,2023-06-26,08:12:00,09:42:00,60,66.0,75,A4,7
#
# 9,8,whoseing lesson,whoseing lesson description,2023-06-29,15:59:00,17:29:00,60,66.0,None,Online,7
